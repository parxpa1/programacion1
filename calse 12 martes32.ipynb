# %% [markdown]
# <a href="https://colab.research.google.com/github/parxpa1/programacion1/blob/main/calse%2012%20martes32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
usuarios= {"ANA":"1234","JUAN":"ABC"}

# %%
try:
  usuario= input("usuario: ").upper()
  pasword= input("contraseña: ")

  if usuario not in usuarios:
    raise KeyError("el ususario no existe")
  if usuarios[usuario] !=pasword:
    raise ValueError("contraseña incorecta")
  else:
    print("bienvenid@,",usuario)

except KeyError as e:
  print("error:", e)
except

# %%
usuarios = {
    "ANA": "1234",
    "JUAN": "abcd"
}

try:
    usuario = input("Usuario: ").upper()
    password = input("Contraseña: ")

    if usuario not in usuarios:
        raise KeyError("El usuario no existe")

    if usuarios[usuario] != password:
        raise ValueError("Contraseña incorrecta")

    else:
        print("Bienvenido,", usuario)

except KeyError as e:
    print("Error:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Usuario: pepe
# Contraseña: pepe
# Error: 'El usuario no existe'

# %%
usuarios = {
    "ANA": "1234",
    "JUAN": "abcd"
}

try:
    usuario = input("Usuario: ").upper()

    if usuario not in usuarios:
        raise KeyError("El usuario no existe")

    elif usuarios[usuario] != input("Contraseña: "):
      raise ValueError("Contraseña incorrecta")

    else:
        print("Bienvenido,", usuario)

except KeyError as e:
    print("Error:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Usuario: juan
# Contraseña: abcd
# Bienvenido, JUAN

# %%
try:
  num1 = float(input("numero 1: "))
  num2 = float(input("numero 2: "))
  op = input("operacion: ")
  if op == "+":
    resultado=(num1+num2)
  elif op == "-":
    resultado=(num1-num2)
  elif op == "*":
    resultado=(num1*num2)
  elif op == "/":
    resultado=(num1/num2,num1%num2)
  else:
    raise("operacion no valida")
  print("resultado:", resultado)
except ValueError as e:
  print("error:", e)
except ZeroDivisionError as e:
  print("error:", e)
except Exception as e:
  print("error:", e)
# Out:
# numero 1: p
# error: could not convert string to float: 'p'

# %% [markdown]
# Let's demonstrate how the current code handles non-numeric input. Try running the cell below and entering a letter for 'numero 1':

# %%
try:
  num1 = float(input("numero 1: "))
  num2 = float(input("numero 2: "))
  op = input("operacion: ")
  if op == "+":
    resultado=(num1+num2)
  elif op == "-":
    resultado=(num1-num2)
  elif op == "*":
    resultado=(num1*num2)
  elif op == "/":
    resultado=(num1/num2,num1%num2)
  else:
    raise Exception("operacion no valida")
  print("resultado:", resultado)
except ValueError as e:
  print("error:", e)
except ZeroDivisionError as e:
  print("error:", e)
except Exception as e:
  print("error:", e)
# Out:
# numero 1: p
# error: could not convert string to float: 'p'

# %%
try:
    datos = input("Ingresa números separados por coma: ")
    lista = [int(x) for x in datos.split(",")]

    indice = int(input("Índice a consultar: "))
    print("Elemento:", lista[indice])

except ValueError:
    print("Debes ingresar solo números")

except IndexError:
    print("El índice está fuera de rango")
# Out:
# Ingresa números separados por coma: 1,2,3,4,1,1
# Índice a consultar: 5
# Elemento: 1
