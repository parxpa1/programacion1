# %% [markdown]
# #NOTEBOOK ESTRUCTURAS DE DATOS CON PYTHON
#
# ---
#
#
# ### Hola tú, quién lees este Notebook, antes de nada gracias por haber elegido mi vídeo para aprender Python.
#
# ###Si has llegado a este Notebook por otro medio que no sea mi vídeo, te dejo el enlace para que puedas ver y entender este cuaderno.
#
# ![ThumbnailColab2.png](data:image/png;base64,...)
#
# ##[ENLACE AL VÍDEO EN YOUTUBE: Estructuras de datos con Python en 8 minutos](https://youtu.be/v25-m1LOUiU)
#
# ### Primero mira el vídeo donde te explicaré lo básico de las estructuras de Python: Listas, Tuplas, Conjuntos y Diccionarios.
#
# ###¡Piensa los ejercicios que hay al final del vídeo antes de leer este cuaderno! Luego, anota tus respuestas y vuelve aquí para consultar al final de este cuaderno si coinciden con las que has anotado.
#
# ###Cualquier duda me la puedes dejar en los comentarios de YouTube.
#
# ###Si te he ayudado a empezar con las estructuras de datos, recuerda que puedes ayudarme tú a mí con tu suscripción y así poder seguir ayudándote con otros vídeos ;)
#
# ###¡Nos vemos!
# ###BitBoss

# %%
# Listas

lista = [29, True, 3.1415, "El número de Avogadro sí que mola"]

print(lista)
print(lista[-1])
print(lista[1:3])

lista[2] = "He cambiado este elemento"

lista[2] = [3, 2, 1]
print(lista)

print(len(lista))

# %%
lista = [29, True, 3.1415, "El número de Avogadro sí que mola"]

print(lista)
print(lista[-1])
print(lista[1:-1])#por alguna razon, aqui no cuenta el -1 como -1 sino que toma el -2 como -1

lista[2] = "He cambiado este elemento"

lista[2] = [3, 2, 1]
print(lista)

print(len(lista))
# Out:
# [29, True, 3.1415, 'El número de Avogadro sí que mola']
# El número de Avogadro sí que mola
# [True, 3.1415]
# [29, True, [3, 2, 1], 'El número de Avogadro sí que mola']
# 4

# %%
lista = [29, True, 3.1415, "El número de Avogadro sí que mola"]

print(lista)
print(lista[-1])
print(lista[1:3:4])#no se puede repetir un valor al momento de esto, ejemplo, no se puede repetir el 3, sale error

lista[2:4] = "He cambiado este elemento"#puede replazar mas de un solo elemento

lista[2] = [3, 2, 1]
print(lista)

print(len(lista))
# Out:
# [29, True, 3.1415, 'El número de Avogadro sí que mola']
# El número de Avogadro sí que mola
# [True]
# [29, True, [3, 2, 1], 'e', ' ', 'c', 'a', 'm', 'b', 'i', 'a', 'd', 'o', ' ', 'e', 's', 't', 'e', ' ', 'e', 'l', 'e', 'm', 'e', 'n', 't', 'o']
# 27

# %%
lista_nueva = [1, 2, 3, 4, 5]

lista_nueva.append(3)

print(lista_nueva)

print(lista_nueva.count(3))

print(lista_nueva.index(4))

lista_nueva.remove(3)

print(lista_nueva)
# Out:
# [1, 2, 3, 4, 5, 3]
# 2
# 3
# [1, 2, 4, 5, 3]

# %%
# Tuplas

tupla = ("¿La tierra es plana?", True, False)
print(tupla)

print(tupla[0])
print(tupla[1])
print(tupla[2])

print(tupla.count(True))
print(tupla.index(False))

print((1))
print((1,))

# %%
# Conjunto

print(set())

print(set([5, 2, 5, 1, 1.5]))
print(set((5, 2, 5, 1, 1.5)))
print(set("52511.5"))

conjunto = set([2, 3, 3, 4])
conjunto_2 = set([5, 3, 5, 6])
conjunto_3 = set([4, 2])

print(conjunto)
print(conjunto_2)
print(conjunto_3)

conjunto.add(1)
print(conjunto)

conjunto.remove(1)
print(conjunto)

print(conjunto.intersection(conjunto_2))
print(conjunto_2.issubset(conjunto))
print(conjunto_3.issubset(conjunto))
print(conjunto_3.issubset(conjunto_2))
# Out:
# set()
# {1, 2, 5, 1.5}
# {1, 2, 5, 1.5}
# {'1', '.', '5', '2'}
# {2, 3, 4}
# {3, 5, 6}
# {2, 4}
# {1, 2, 3, 4}
# {2, 3, 4}
# {3}
# False
# True
# False

# %%
# Diccionario

diccionario = {1: "Uno", 2: "Dos"}
diccionario[3] = "Tres"
print(diccionario)

dict_lista_tuplas = dict([(1, "Uno"), (2, "Dos"), (3, "Tres")])
print(dict_lista_tuplas)

dict_lista_string = dict(Uno = 1, Dos = 2, Tres = 3)
print(dict_lista_string)

dict_tipos = {1: "integer",
              2.2: "float",
              "texto": "string",
              (1, 2): "tupla"}

print(dict_tipos)

dict_repeticion = {1: "Primero", 1: "Último"}
print(dict_repeticion)

print(diccionario,
      diccionario.keys(),
      diccionario.values(),
      diccionario.items())

claves = diccionario.values()
print(claves)
diccionario[1] = "One"
print(claves)
diccionario.pop(2)
print(diccionario)

# %% [markdown]
# # **Aquí os dejo los resultados de los ejercicios del final del vídeo:**
#
# ### Ejercicio Listas:

# %%
personajes = ["Kakyoin", "Joseph", "Jotaro"]
personajes.remove("Kakyoin")
personajes.append("Polnareff")
resultado = personajes[1:2]
print(resultado)
# Out:
# ['Jotaro']

# %% [markdown]
# ###Ejercicio Tuplas:

# %%
respuesta = ("Yes","Yes","Yes")
resultado = (respuesta.count("Yes"), respuesta.index("Yes"))
print(resultado)

# %% [markdown]
# ###Ejercicio Conjuntos:

# %%
temporada_2 = set(["Joseph", "Caesar"])
temporada_3 = set(["Jotaro", "Joseph", "Avdol", "Kakyoin", "Polnareff"])
resultado = temporada_2 & temporada_3
print(resultado)

# %% [markdown]
# ###Ejercicio Diccionarios:

# %%
protas = {1: "Jonnathan", 2: "Joseph", 3: "Jotaro"}
jojos = {"Jonnathan": "Phantom Blood",
         "Joseph": "Battle Tendency",
         "Jotaro": "Stardust Crusaders"}
resultado = jojos[protas[3]]
print(resultado)
