# %% [markdown]
# <a href="https://colab.research.google.com/github/parxpa1/programacion1/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("ingrese un estudiante: ")

def pedir_notas():
  n1=float()
# Out:
# Writing pedirnotas.py

# %%
# %%writefile pedirnotas.py
def calcular_promedio(n1, n2, n3):
  return (n1+n2+n3)/3
# Out:
# Overwriting pedirnotas.py

# %%
prom = print(calcular_promedio(n1,n2,n3))
print("estudiante:",nombre)
print("prodmedio: ", prom)
if prom >= 3:
  print("aprobo")
else:
  print("reprobo")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9008/1686331523.py in <cell line: 0>()
# ----> 1 prom = print(calcular_promedio(n1,n2,n3))
#       2 print("estudiante:",nombre)
#       3 print("prodmedio: ", prom)
#       4 if prom >= 3:
#       5   print("aprobo")
#
# NameError: name 'calcular_promedio' is not defined

# %%
from IPython.core.inputtransformer2 import PromptStripper
inport PromptStripper
prom = promedio.calcular_promedio(n1,n2,n3)
print("estudiante:",nombre)
print("prodmedio: ", prom)
if prom >= 3:
  print("aprovo")
else:
  print("reprobo")
# Out:
#   File "/tmp/ipykernel_9008/54040772.py", line 2
#     inport PromptStripper
#            ^
# SyntaxError: invalid syntax

# %%
# %%writefile pedirnotas.py
def suma(a,b):
  return a+b
def multiplicar(a,b):
  return a*b
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile pedirnotas.py
def saludar (nombre):
  return f"hola(nombre)"
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile pedirnotas.py
inport statistics
def cañcular.promedio(n1,n2,n3):
  return(n1,n2,n3)/3
def mediana (n1,n2,n3):
  return statistics.median([n1,n2,n3])
# Out:
# Overwriting pedirnotas.py

# %%
import os
os.makedirs("src", exist_ok=True)

# %%
from src.operaciones import dividir
print(dividir(10,2))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_9008/1441605853.py in <cell line: 0>()
# ----> 1 from src.operaciones import dividir
#       2 print(dividir(10,2))
#
# ModuleNotFoundError: No module named 'src.operaciones'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import src.operaciones
print(src.operaciones.dividir(10,2))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_9008/938420830.py in <cell line: 0>()
# ----> 1 import src.operaciones
#       2 print(src.operaciones.dividir(10,2))
#
# ModuleNotFoundError: No module named 'src.operaciones'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
