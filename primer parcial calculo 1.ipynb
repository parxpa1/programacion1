# %% [markdown]
# <a href="https://colab.research.google.com/github/parxpa1/programacion1/blob/main/primer%20parcial%20calculo%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instrucción 1: Construya dos conjuntos A y B en Python con valores enteros de su elección. Los
# conjuntos deben cumplir que tengan al menos dos elementos en común y al menos un elemento
# diferente entre ellos. Una vez definidos los conjuntos, utilice el siguiente método:

# %%
A = {"A" , "B", "C"}
B = {"B", "C", "D"}
A.difference(B)
# Out:
# {'A'}

# %%
A = {"A" , "B", "C"}
B = {"B", "C", "D"}
A.symmetric_difference(B)
# Out:
# {'A', 'D'}

# %% [markdown]
# Muestra cual es el elemento que tiene A diferente de B
# symmetric_difference: es para hacer que se muestren los valores que no estan ni en uno ni en el otro

# %% [markdown]
# Instrucción 2: Defina dos conjuntos A y B con valores de su elección, de manera que todos los
# elementos de B estén contenidos dentro del conjunto A. Posteriormente utilice el siguiente método:

# %%
A = {1, 2, 3, 4, 5}
B = {1, 3, 5}
A.issuperset(B)
# Out:
# True

# %%
A = {1, 2, 3, 4, 5}
B = {1, 3, 5}
A.isdisjoint(B)
# Out:
# False

# %% [markdown]
# A.issuperset(B) Hace que el texto devuelva si es verdad o no si todos los valores del conjunto B estan contenidos en el conjunto A

# %% [markdown]
# isdisjoint. No dedusco que hace

# %% [markdown]
# Instrucción 3: Defina un diccionario llamado datos2 con al menos dos pares clave:valor de su
# elección. Posteriormente utilice la siguiente instrucción de Python:

# %%
datos2 = {"comida": "pastas", "dia": 12}
datos2.update({"mes": "sept"})
print(datos2)
# Out:
# {'comida': 'pastas', 'dia': 12, 'mes': 'sept'}

# %%
datos2 = {"comida": "pastas", "dia": 12}
datos2.update({"comida": "pastas"})
print(datos2)
# Out:
# {'comida': 'pastas', 'dia': 12}

# %% [markdown]
# uppdate hace que el nuevo par de clave: valor sea añadido al conjunto designado

# %% [markdown]
# si ponemos un clave: valor que ya este en el diccionionario no ocurrira nada, solamente no se pondrá en el diccionario

# %% [markdown]
# Instrucción 4: Defina un diccionario llamado datos3 con al menos dos pares clave:valor de su
# elección. Posteriormente implemente la siguiente instrucción de Python:

# %%
datos3 = {"comida": "pastas", "dia": 12}
datos3.setdefault("año", 2008)
# Out:
# 2008

# %%
datos3 = {"comida": "pastas", "dia": 12}
datos3.setdefault("comida", "pollo")
# Out:
# 'pastas'

# %%
datos3 = {"comida": "pastas", "dia": 12}
datos3.setdefault("dia", 12)
# Out:
# 12

# %% [markdown]
# setdefault imprime el valor de la llave y valor ingresados

# %% [markdown]
# si se pone un valor diferente al anterior de la llave, el metodo imprimira el valor original de la lláve

# %% [markdown]
# si se pone una clave, valor repetida el programa imprime la llave de esa llave

# %% [markdown]
# Parte III: Salidas de instrucciones no asignadas (25/100): Realice los siguientes programas
# en lenguaje Python. Puede ayudarse de los códigos de ayuda. Ejecute los códigos y registre los
# resultados obtenidos en el mismo archivo .ipynb de la parte II. Posteriormente, cree el enlace
# de su repositorio en GitHub, cópielo y péguelo en un archivo PDF. Finalmente, suba dicho
# archivo a la plataforma Moodle del curso.

# %% [markdown]
# Código 1: Diseñe una función en Python que cumpla con las siguientes condiciones:
#  Permita recibir como entrada diferentes tipos de datos (números enteros, decimales o texto).
#  Veri􀏐ique que el número sea natural (entero y mayor o igual a cero).
#  Recorra los números desde 0 hasta m:
# - Para 0 y 1, imprima el número.
# - Para los demás, determine si son primos o no.
# - Si no es primo, muestre una factorización básica.
# Ejecute la función con la entrada m = 5 y m = "a"

# %%
m = 5
if isinstance(m, int) and m >= 0:
  print("m mayor o igual a 0")
  for n in range(0, (m+1)):
    if n == 1 or n == 0:
      print("El número es ", n)
    else:
      for x in range(2, n):
        if n % x == 0:
          print(n, 'es igual a', x, '*', n // x)
          break
      else: # Este else corresponde al for, no al if
          print(n, 'es un número primo')
else:
  print("ingrese un numero natural")
# Out:
# m mayor o igual a 0
# El número es  0
# El número es  1
# 2 es un número primo
# 3 es un número primo
# 4 es igual a 2 * 2
# 5 es un número primo

# %%
m = "a"
if isinstance(m, int) and m >= 0:
  print("m mayor o igual a 0")
  for n in range(0, (m+1)):
    if n == 1 or n == 0:
      print("El número es ", n)
    else:
      for x in range(2, n):
        if n % x == 0:
          print(n, 'es igual a', x, '*', n // x)
          break
      else: # Este else corresponde al for, no al if
          print(n, 'es un número primo')
else:
  print("ingrese un numero natural")
# Out:
# ingrese un numero entero

# %%
m = -3
if isinstance(m, int) and m >= 0:
  print("m mayor o igual a 0")
  for n in range(0, (m+1)):
    if n == 1 or n == 0:
      print("El número es ", n)
    else:
      for x in range(2, n):
        if n % x == 0:
          print(n, 'es igual a', x, '*', n // x)
          break
      else: # Este else corresponde al for, no al if
          print(n, 'es un número primo')
else:
  print("ingrese un numero natural")
# Out:
# ingrese un numero natural

# %% [markdown]
# Código 2: Cree una función cuya entrada sea un objeto tipo str, el cual cuente:
#  Vocales mayúsculas y minúsculas,
#  Consonantes mayúsculas y minúsculas,
#  números y
#  otros caracteres (como espacios, números o sı́mbolos)
# La salida de la función es un diccionario con la cantidad total de vocales, consonantes y otros
# caracteres encontrados en el texto.
# Ejecute la función con una cadena ingresada por el usuario.

# %%
def contador_vocales1(palabra):
  vocales = "aeiou"
  vocales2 = vocales.upper()
  consonantes = "bcdfghjklmnñpqrstvwxyz"
  consonantes2 = consonantes.upper()
  contador = 0
  contadorV = 0
  contador1 = 0
  contador2 = 0
  contador3 = 0
  for letra in palabra():
    if letra in vocales:
      contador += 1
    elif letra in palabra():
      if letra in vocales2:
        contadorV += 1
    elif letra in consonantes:
      contador1 += 1
    elif letra in consonantes2:
      contador3 += 1
    else:
      contador2 += 1
  return({"Cantidad de vocales:": contador,"Cantidad de vocales mayusculas:": contadorV,"Cantidad de consonates:": contador1,"Cantidad de consonates mayusculas:": contador3,"Cantidad de otros caracteres:": contador2})

# %%
palabra = "pollo"
contador_vocales1(palabra)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_748/1488114803.py in <cell line: 0>()
#       1 palabra = "pollo"
# ----> 2 contador_vocales1(palabra)
#
# /tmp/ipykernel_748/3526704361.py in contador_vocales1(palabra)
#       9   contador2 = 0
#      10   contador3 = 0
# ---> 11   for letra in palabra():
#      12     if letra in vocales:
#      13       contador += 1
#
# TypeError: 'str' object is not callable
