# %% [markdown]
# <a href="https://colab.research.google.com/github/parxpa1/programacion1/blob/main/moda19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
inport statistics
def cacular.promedio(n1,n2,n3):
  return(n1,n2,n3)/3
def mediana (n1,n2,n3):
  return statistics.median([n1,n2,n3])
def moda(n1,n2,n3):
  return statistics.mode([n1,n2,n3])
# Out:
# Overwriting pedirnotas.py

# %%
notas = str(input("introduce 3 notas: "))
nombre = str(input("introduce tu nombre: "))
media = mediana(notas)/3
print(media)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11607/960593894.py in <cell line: 0>()
# ----> 1 notas = string(input("introduce 3 notas: "))
#       2 nombre = str(input("introduce tu nombre: "))
#       3 media = mediana(notas)/3
#       4 print(media)
#
# NameError: name 'string' is not defined

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
    return input("Ingrese el nombre del estudiante: ")

def pedir_():
    n1 = float(input("Nota 1: "))
    n2 = float(input("Nota 2: "))
    n3 = float(input("Nota 3: "))
    return n1, n2, n3
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
import statistics
def calcular_promedio(n1, n2, n3):
    return (n1 + n2 + n3) / 3

def mediana(n1, n2, n3):
  return statistics.median([n1, n2, n3])

def moda(n1,n2,n3):
  return statistics.mode([n1,n2,n3])

import pedirnotas
nombre = pedirnotas.pedir_nombre()

import importlib
import pedirnotas
importlib.reload(pedirnotas)
notas = pedirnotas.pedir_()

importlib.reload(promedio)
prom = promedio.calcular_promedio(notas[0], notas[1], notas[2])
mediana_ = promedio.mediana(notas[0], notas[1], notas[2])

print("Estudiante:", nombre)
print("Promedio:", prom)
print("Mediana:", prom)

if prom >= 3:
    print("Aprobó")
else:
    print("Reprobó")
# Out:
# Overwriting promedio.py

# %%
import statistics
def calcular_promedio(n1, n2, n3):
    return (n1 + n2 + n3) / 3

def mediana(n1, n2, n3):
  return statistics.median([n1, n2, n3])

def moda(n1,n2,n3):
  return statistics.mode([n1,n2,n3])

import pedirnotas
nombre = pedirnotas.pedir_nombre()

import importlib
import pedirnotas
importlib.reload(pedirnotas)
notas = pedirnotas.pedir_()

importlib.reload(promedio)
prom = promedio.calcular_promedio(notas[0], notas[1], notas[2])
mediana_ = promedio.mediana(notas[0], notas[1], notas[2])

print("Estudiante:", nombre)
print("Promedio:", prom)
print("Mediana:", prom)

if prom >= 3:
    print("Aprobó")
else:
    print("Reprobó")
# Out:
# Ingrese el nombre del estudiante: j
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipykernel_11607/3159761505.py", line 16, in <cell line: 0>
#     importlib.reload(pedirnotas)
#
#   File "/usr/lib/python3.12/importlib/__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#
#   File "<frozen importlib._bootstrap_external>", line 1133, in get_code
#
#   File "<frozen importlib._bootstrap_external>", line 1063, in source_to_code
#
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#
#   File "/content/pedirnotas.py", line 1
#     inport statistics
#            ^
# SyntaxError: invalid syntax

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
    return input("Ingrese el nombre del estudiante: ")

def pedir_():
    n1 = float(input("Nota 1: "))
    n2 = float(input("Nota 2: "))
    n3 = float(input("Nota 3: "))
    n4 = float(input("Nota 4: "))
    return n1, n2, n3, n4
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
import statistics
def calcular_promedio(n1, n2, n3, n4):
    return (n1 + n2 + n3+n4) / 4

def mediana(n1, n2, n3, n4):
  return statistics.median([n1, n2, n3, n4])

def moda(n1,n2,n3,n4):
  return statistics.moda([n1,n2,n3,n4])
# Out:
# Overwriting promedio.py

# %%
import pedirnotas
nombre = pedirnotas.pedir_nombre()

import importlib
import pedirnotas
import promedio
importlib.reload(pedirnotas)
notas = pedirnotas.pedir_()

importlib.reload(promedio)
prom = promedio.calcular_promedio(notas[0], notas[1], notas[2], notas[3])
mediana_ = promedio.mediana(notas[0], notas[1], notas[2],notas[3])

print("Estudiante:", nombre)
print("Promedio:", prom)
print("Mediana:", prom)

if prom >= 3:
    print("Aprobó")
else:
    print("Reprobó")
# Out:
# Ingrese el nombre del estudiante: pe
# Nota 1: 10
# Nota 2: 20
# Nota 3: 30
# Nota 4: 40
# Estudiante: pe
# Promedio: 25.0
# Mediana: 25.0
# Aprobó
