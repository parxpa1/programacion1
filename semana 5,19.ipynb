# %% [markdown]
# <a href="https://colab.research.google.com/github/parxpa1/programacion1/blob/main/semana%205%2C19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cadena2 = "Hola mundo"
dir(cadena2)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
cadena2 = "Hola mundo"
((cadena2.lower()).capitalize()).islower()
# Out:
# False

# %%
cadena2 = "Hola mundo"
cadena2.islower()
# Out:
# False

# %%
def mayusculas (cadena):
    return cadena.upper()

mayusculas("casa")
# Out:
# 'CASA'

# %%
cadena2.startswith("H")
# Out:
# True

# %%
cadena2.endswith("o")
# Out:
# True

# %%
cadena_nueva = cadena2.replace("mundo", "python")
cadena_nueva
# Out:
# 'Hola python'

# %%
cadena_nueva.replace(" ","").split()
# Out:
# ['Holapython']

# %%
len(cadena_nueva.split())
# Out:
# 2

# %%
cadena7 = "hola  hola  chao"
cadena7.split()
# Out:
# ['hola', 'hola', 'chao']

# %%
lista = "a","b","c","d","f","g","h","i","j","k","l","m"
print (lista.append("n"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_279/257815129.py in <cell line: 0>()
#       1 lista = "a","b","c","d","f","g","h","i","j","k","l","m"
# ----> 2 print (lista.append("n"))
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
cadena2.pop(H)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_279/719339785.py in <cell line: 0>()
# ----> 1 cadena2.pop(H)
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
lista8 = [1,2,3,4,4,5]
lista8.remove(4)
lista8
# Out:
# [1, 2, 3, 4, 5]

# %%
wjile 4 in lista8:
    lista.remove(4)
lista8
# Out:
#   File "/tmp/ipykernel_279/431282601.py", line 1
#     wjile 4 in lista8:
#           ^
# SyntaxError: invalid syntax

# %%
lista2 = ["a","c","b"]
lista2.sort(reverse=True)
lista2
# Out:
# ['c', 'b', 'a']

# %%
tupla = (1,2,3,4,5)
tupla.extend((6,7,8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_279/735927164.py in <cell line: 0>()
#       1 tupla = (1,2,3,4,5)
# ----> 2 tupla.extend((6,7,8))
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
tupla.index(3)
# Out:
# 2

# %%
dir(tupla)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
tupla.count(4)
# Out:
# 1

# %%
conjunto = {1,2,3,4,5}
conjunto.add("a")
conjunto
# Out:
# {1, 2, 3, 4, 5, 'a'}

# %%
conjunto1 = conjunto.union({"6","7","8"})	¨
conjunto1
# Out:
#   File "/tmp/ipykernel_279/1051084983.py", line 1
#     conjunto1 = conjunto.union({"6","7","8"})	¨
#                                              	^
# SyntaxError: invalid character '¨' (U+00A8)
