# %% [markdown]
# <a href="https://colab.research.google.com/github/parxpa1/programacion1/blob/main/pyton3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad = 17
tiene_cedula = True
if edad >= 18 and tiene_cedula:
  print ("puede votar")
else:
  print ("no puede votar")
# Out:
# no puede votar

# %%
dia = "domingo"

if dia == "sabado" or dia == "domingo":
  print ("fin de semana")
# Out:
# fin de semana

# %%
i = input ("ingrse el dia(L, M, MI, J, V, S, D)")
dia = ["L","M","MI","J","V","S","D"]
if i == "S" or i == "D":
  print ("fin de semana")
else:
  print ("entre semana")
# Out:
# ingrse el dia(L, M, MI, J, V, S, D)L
# entre semana

# %%
A = False
B = True

if A ^ B:
  print ("xor true")
else:
  print ("xor false")
# Out:
# xor true

# %%
import numpy as np

num_range = list(range(1, 30))
# Define 'n' before using it for random choice, assuming 'n' refers to the number of samples
# For demonstration, let's set a value for 'n', e.g., 5, or derive it from num_range
n_samples = 5 # Example: choose 5 random numbers
numeros_elegidos = np.random.choice(num_range, n_samples, replace=False) # Use replace=False if you want unique numbers

for n in num_range:
    if n in numeros_elegidos: # Corrected 'is' to 'in' for checking membership and removed extra colon
        # Assuming 'a' was meant to be 'n' for a condition here
        if n < 10:
            print(f"{n} (chosen and < 10)")
        else:
            print(f"{n} (chosen)")
    else:
        # Original condition `n[0:11]` suggests `n` might be a string or list, but it's an int here.
        # This part of the else needs clarification. For now, assuming it meant to print numbers not chosen.
        print(f"{n} (not chosen)")
# Out:
# 1 (not chosen)
# 2 (not chosen)
# 3 (not chosen)
# 4 (chosen and < 10)
# 5 (not chosen)
# 6 (not chosen)
# 7 (not chosen)
# 8 (not chosen)
# 9 (chosen and < 10)
# 10 (not chosen)
# 11 (not chosen)
# 12 (not chosen)
# 13 (not chosen)
# 14 (not chosen)
# 15 (not chosen)
# 16 (not chosen)
# 17 (not chosen)
# 18 (not chosen)
# 19 (chosen)
# 20 (chosen)
# 21 (not chosen)
# 22 (not chosen)
# 23 (not chosen)
# 24 (not chosen)
# 25 (not chosen)
# 26 (not chosen)
# 27 (not chosen)
# 28 (not chosen)
# 29 (chosen)

# %%
vocales = ("a", "e", "i", "o", "u")
palabra = "carro"
if vocales in palabra:
  print ("1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1605355158.py in <cell line: 0>()
#       1 vocales = ("a", "e", "i", "o", "u")
#       2 palabra = "carro"
# ----> 3 if vocales in palabra:
#       4   print ("1")
#
# TypeError: 'in <string>' requires string as left operand, not tuple

# %%
lista = [10, 20 30]
index = int(input("ingrese un indice; "))
try:

# %%
palabra = (murcielago)
try:
  index = input("Ingresa un índice: ")
    if type(letra) == str and letra in palabra:
      print ("la letra encontrada es:", letra)
    elif type (letra) not in palabra:
      print ("la letra no esta en la palabra")
except valueerror:
  print ("debes ingresar una letra")
# Out:
#   File "/tmp/ipython-input-2101845632.py", line 4
#     if type(letra) == str and letra in palabra:
#     ^
# IndentationError: unexpected indent

# %%
clave_correcta = "python123"
intentos = 3
while intentos > 0:
    intento = input("Ingresa la contraseña: ")
    if intento == clave_correcta:
      print ("acceso concedido")
      break
    else:
      intentos -= 1
      print ("intentos restantes:", intentos)
else:
  print ("cuenta bloqueada")
