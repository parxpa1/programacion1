# %% [markdown]
# <a href="https://colab.research.google.com/github/parxpa1/programacion1/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# manejo de errores u eccepcciones

# %%
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_10889/2211229741.py in <cell line: 0>()
# ----> 1 x=10/0
#
# ZeroDivisionError: division by zero

# %%
try:
  x = int(input("introduce un numero:"))
  print(10 / x)
except value error:
  print("no ingresaste un numero valido")
except ZeroDivisionError:
  print("no puedes dividir por cero")
# Out:
#   File "/tmp/ipykernel_10889/2125440024.py", line 4
#     except value error:
#                  ^
# SyntaxError: invalid syntax

# %%
try:
  x = int(input("introduce un numero:"))
  print(10 / x)
except ZeroDivisionError:
  print("no puedes dividir por cero")
except ValueError:
  print("no ingresaste un numero valido")
# Out:
# introduce un numero:1
# 10.0

# %%
lista= [1,2,3,4,5]
try:
  x = int(input("introduce un numero:"))
  print(lista[x])
except (IndexError, TypeError, ValueError)as e:
  print(f"ocurrio un error: {e}")
# Out:
# introduce un numero:(-5)**2
# ocurrio un error: invalid literal for int() with base 10: '(-5)**2'

# %%
try:
  x= int(input("numero: "))
  print("todo slio bien:", x)
except ValueError:
  print("error en la convercion")
finally:
    print("siempre se ejecuta")
# Out:
# numero: p
# error en la convercion
# siempre se ejecuta

# %%
try:
  edad= int(input("introduce tu edad:"))
  print("edad valida", edad)
  if edad < 0:
    raise ValueError("no se permiten edades negativas")
except ValueError as e:
  print("error:", e)
# Out:
# introduce tu edad:a
# error: invalid literal for int() with base 10: 'a'

# %%
try:
  dato= input("ingrese un numero: ")
  numero = float(dato)
  print("numero:", numero)
except ValueError as e:
  print("value error: ", e)
# Out:
# ingrese un numero: 6
# numero: 6.0

# %%
try:
  dato= input("ingrese un numero: ")
  numero = complex(dato)
  print("numero:", numero)
except ValueError as e:
  print("value error: ", e)
# Out:
# ingrese un numero: 23+67j
# numero: (23+67j)

# %% [markdown]
# "hola" * 7

# %%
try:
  texto = input("ingrese un texto: ")
  numero =input("ingrese un numero: ")
  resultado = texto + numero
  print(resultado)
except (TypeError,) as e:
  print("typeerror: ", e)
# Out:
# ingrese un texto: casa
# ingrese un numero: 6
# casa6

# %%
try:
  lista = input("ingresen elementos separados por comas: "). split(",")
  indice = int(input("ingrese un indice: "))
  print(lista[indice])
except (IndexError) as e:
  print("error: ", e)
except ValueError as e:
  print("error: ", e)
# Out:
# ingresen elementos separados por comas: 4,5,6
# ingrese un indice: q
# error:  invalid literal for int() with base 10: 'q'

# %%
dic = {"a": 1}
dic[b]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10889/1450605026.py in <cell line: 0>()
#       1 dic = {"a": 1}
# ----> 2 dic[b]
#
# NameError: name 'b' is not defined

# %%
try:
  dic={"a": 1, "b":2}
  clave = input("ingrese una clave (a/b): ")
  print("valor: ", dic[clave])
except KeyError as e:
  print("error: ", "el usuario definido no existe")
# Out:
# ingrese una clave (a/b): a
# valor:  1

# %%
carro = 4
try:
  nombre_variable = input ("ingrese el nombre de la variable: ")
  print(eval(nombre_variable))
except NameError as e:
  print("nameerror: ", e)
# Out:
# ingrese el nombre de la variable: carro
# 4

# %%
try:
  a= float(input("numero1: "))
  b=float(input("numero2: "))
  print("resultado: ",a/b)
except ZeroDivisionError as e:
  print("al dividir entre cero se obtiene una indeterminacion ")
# Out:
# numero1: 1
# numero2: 2
# resultado:  0.5

# %%
try:
  a= int(input("numero: "))
  b= input("cadena: ")
  c= input("escoja una operacion(+,-,*,/)")
  print("resultado: ",a/b)
except ZeroDivisionError as e:
  print("al dividir entre cero se obtiene una indeterminacion ")

# %%
try:
  a=int(input("numero1: "))

# %%
open("archivo_inexistente.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10889/442054591.py in <cell line: 0>()
# ----> 1 open("archivo_inexistente.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'archivo_inexistente.txt'
